# %%
import xlrd
# comentarios
#path: direccion de archivo

import os
import pandas as pd
import numpy as np
import array as arr
import altair as alt

pd.set_option("display.max_columns",None)

# %%
gastoIES = pd.read_excel("n2017_PY_Gasto_en_Salud_por_Fuente_de_Financiamiento_1993-2017.xlsx")
gastoIES=gastoIES[["Anio","Estado_Abreviado","EstadoPrint","IES_GPTS_porcentaje_PIB","PIBmxn","IES_GPTS_porcentaje_GPT","IES_GPS_PERCAPITA_Total_n2017"]]
gastoIES=gastoIES[gastoIES.Estado_Abreviado != "EUM"].rename(columns={"Estado_Abreviado":"Estado","IES_GPTS_porcentaje_PIB":"PIB","IES_GPTS_porcentaje_GPT":"GPT","IES_GPS_PERCAPITA_Total_n2017":"PERCAPITA"})

# %%
periodo = 6
sexenios = [i for i in range(gastoIES.Anio.min(), gastoIES.Anio.max()+periodo, periodo)]
sexenios=[1995,2001,2007,2013,2018]
print(sexenios)

sexeniosCol = pd.cut(gastoIES.Anio, bins=sexenios, precision=0, right=False)
gastoIES.insert(1, "sexenio", sexeniosCol)
gastoIES.head()
# Out:
# [1995, 2001, 2007, 2013, 2018]
#    Anio       sexenio Estado          EstadoPrint       PIB        PIBmxn  \
# 1  1995  [1995, 2001)    AGS       Aguascalientes  2.278928  7.917746e+07
# 2  1995  [1995, 2001)     BC      Baja California  2.163063  2.294365e+08
# 3  1995  [1995, 2001)    BCS  Baja California Sur  3.742114  3.864674e+07
# 4  1995  [1995, 2001)   CAMP             Campeche  1.537610  9.870427e+07
# 5  1995  [1995, 2001)   COAH             Coahuila  2.400249  2.400484e+08
#
#          GPT    PERCAPITA
# 1  10.647619  1959.069682
# 2  22.601979  2317.759096
# 3  21.956918  3609.493866
# 4   6.582009  2409.419805
# 5  17.083340  2621.670253

# %%
new_labels = ["S1", "S2", "S3", "S4"]
gastoIES["sexenio"] = gastoIES["sexenio"].cat.rename_categories(new_labels)

# %%
# gastoIES["PIB"] = (gastoIES["PIB"]/100).apply(lambda x: '{:.2%}'.format(x))

# %%
# gastoIES["GPT"] = (gastoIES["GPT"]/100).apply(lambda x: '{:.2%}'.format(x))

# %%
gastoIES
# Out:
#      Anio sexenio Estado          EstadoPrint       PIB        PIBmxn  \
# 1    1995      S1    AGS       Aguascalientes  2.278928  7.917746e+07
# 2    1995      S1     BC      Baja California  2.163063  2.294365e+08
# 3    1995      S1    BCS  Baja California Sur  3.742114  3.864674e+07
# 4    1995      S1   CAMP             Campeche  1.537610  9.870427e+07
# 5    1995      S1   COAH             Coahuila  2.400249  2.400484e+08
# ..    ...     ...    ...                  ...       ...           ...
# 754  2017      S4  TAMPS           Tamaulipas  3.181874  6.078901e+08
# 755  2017      S4   TLAX             Tlaxcala  4.977256  1.154003e+08
# 756  2017      S4    VER             Veracruz  3.916907  9.402165e+08
# 757  2017      S4    YUC              Yucatán  4.249854  3.004113e+08
# 758  2017      S4    ZAC            Zacatecas  3.747525  1.971711e+08
#
#            GPT    PERCAPITA
# 1    10.647619  1959.069682
# 2    22.601979  2317.759096
# 3    21.956918  3609.493866
# 4     6.582009  2409.419805
# 5    17.083340  2621.670253
# ..         ...          ...
# 754  18.173028  5339.333865
# 755  28.274960  4374.314206
# 756  17.513495  4510.971605
# 757  22.314929  5875.742148
# 758  25.655200  4616.959496
#
# [736 rows x 8 columns]

# %%
gastoSexenios=gastoIES.sort_values(by=["Estado","Anio"],ascending=True).reset_index()
gastoSexenios
# Out:
#      index  Anio sexenio Estado     EstadoPrint       PIB        PIBmxn  \
# 0        1  1995      S1    AGS  Aguascalientes  2.278928  7.917746e+07
# 1       34  1996      S1    AGS  Aguascalientes  1.987116  8.690798e+07
# 2       67  1997      S1    AGS  Aguascalientes  2.143517  9.629624e+07
# 3      100  1998      S1    AGS  Aguascalientes  2.319555  1.003836e+08
# 4      133  1999      S1    AGS  Aguascalientes  2.761372  1.073634e+08
# ..     ...   ...     ...    ...             ...       ...           ...
# 731    626  2013      S4    ZAC       Zacatecas  3.941298  1.694030e+08
# 732    659  2014      S4    ZAC       Zacatecas  3.834181  1.743785e+08
# 733    692  2015      S4    ZAC       Zacatecas  3.856125  1.841990e+08
# 734    725  2016      S4    ZAC       Zacatecas  3.674188  1.918374e+08
# 735    758  2017      S4    ZAC       Zacatecas  3.747525  1.971711e+08
#
#            GPT    PERCAPITA
# 0    10.647619  1959.069682
# 1    10.914541  1838.158261
# 2    13.529886  2155.873869
# 3    13.109835  2388.303511
# 4    15.017065  2989.039477
# ..         ...          ...
# 731  21.766645  4307.035375
# 732  21.374967  4276.775771
# 733  22.107488  4506.750129
# 734  21.830197  4437.413443
# 735  25.655200  4616.959496
#
# [736 rows x 9 columns]

# %%
gastoIES
# Out:
#      Anio sexenio Estado          EstadoPrint       PIB        PIBmxn  \
# 1    1995      S1    AGS       Aguascalientes  2.278928  7.917746e+07
# 2    1995      S1     BC      Baja California  2.163063  2.294365e+08
# 3    1995      S1    BCS  Baja California Sur  3.742114  3.864674e+07
# 4    1995      S1   CAMP             Campeche  1.537610  9.870427e+07
# 5    1995      S1   COAH             Coahuila  2.400249  2.400484e+08
# ..    ...     ...    ...                  ...       ...           ...
# 754  2017      S4  TAMPS           Tamaulipas  3.181874  6.078901e+08
# 755  2017      S4   TLAX             Tlaxcala  4.977256  1.154003e+08
# 756  2017      S4    VER             Veracruz  3.916907  9.402165e+08
# 757  2017      S4    YUC              Yucatán  4.249854  3.004113e+08
# 758  2017      S4    ZAC            Zacatecas  3.747525  1.971711e+08
#
#            GPT    PERCAPITA
# 1    10.647619  1959.069682
# 2    22.601979  2317.759096
# 3    21.956918  3609.493866
# 4     6.582009  2409.419805
# 5    17.083340  2621.670253
# ..         ...          ...
# 754  18.173028  5339.333865
# 755  28.274960  4374.314206
# 756  17.513495  4510.971605
# 757  22.314929  5875.742148
# 758  25.655200  4616.959496
#
# [736 rows x 8 columns]

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoIES.to_excel(writer, sheet_name="gasto")

# %%
gastoSexenios= gastoIES
arrowSexenios= gastoIES
gastoSexenios
# Out:
#      Anio sexenio Estado          EstadoPrint       PIB        PIBmxn  \
# 1    1995      S1    AGS       Aguascalientes  2.278928  7.917746e+07
# 2    1995      S1     BC      Baja California  2.163063  2.294365e+08
# ...          ...    ...   ...     ...         ...       ...           ...
# NAY     4.234037     32  2013      S4     Nayarit  4.652251  1.195352e+08
# NAY     4.234037     32  2014      S4     Nayarit  4.195087  1.245053e+08
# NAY     4.234037     32  2015      S4     Nayarit  4.287882  1.340607e+08
# NAY     4.234037     32  2016      S4     Nayarit  3.981486  1.427993e+08
# NAY     4.234037     32  2017      S4     Nayarit  4.073215  1.505059e+08
#
#               GPT    PERCAPITA
# Estado
# CAMP     6.582009  2409.419805
# CAMP     4.817801  2180.641158
# CAMP     5.386548  2476.466433
# CAMP     4.810215  2707.429223
# CAMP     7.514958  3205.240990
# ...           ...          ...
# NAY     21.766850  4719.165012
# NAY     18.986366  4348.233386
# NAY     19.823885  4697.155252
# NAY     20.340046  4562.289993
# NAY     23.593870  4832.969703
#
# [736 rows x 9 columns]

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoSexenios.to_excel(writer, sheet_name="gasto_Sexenios")

# %%
gastoIES[["PIB","Anio"]]
# Out:
#              PIB  Anio
# Estado
# AGS     2.278928  1995
# BC      2.163063  1995
# BCS     3.742114  1995
# CAMP    1.537610  1995
# COAH    2.400249  1995
# ...          ...   ...
# TAMPS   3.181874  2017
# TLAX    4.977256  2017
# VER     3.916907  2017
# YUC     4.249854  2017
# ZAC     3.747525  2017
#
# [736 rows x 2 columns]

# %%
gastoIES
# Out:
#         Anio sexenio          EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# AGS     1995      S1       Aguascalientes  2.278928  7.917746e+07  10.647619
# BC      1995      S1      Baja California  2.163063  2.294365e+08  22.601979
# BCS     1995      S1  Baja California Sur  3.742114  3.864674e+07  21.956918
# CAMP    1995      S1             Campeche  1.537610  9.870427e+07   6.582009
# COAH    1995      S1             Coahuila  2.400249  2.400484e+08  17.083340
# ...      ...     ...                  ...       ...           ...        ...
# TAMPS   2017      S4           Tamaulipas  3.181874  6.078901e+08  18.173028
# TLAX    2017      S4             Tlaxcala  4.977256  1.154003e+08  28.274960
# VER     2017      S4             Veracruz  3.916907  9.402165e+08  17.513495
# YUC     2017      S4              Yucatán  4.249854  3.004113e+08  22.314929
# ZAC     2017      S4            Zacatecas  3.747525  1.971711e+08  25.655200
#
#           PERCAPITA
# Estado
# AGS     1959.069682
# BC      2317.759096
# BCS     3609.493866
# CAMP    2409.419805
# COAH    2621.670253
# ...             ...
# TAMPS   5339.333865
# TLAX    4374.314206
# VER     4510.971605
# YUC     5875.742148
# ZAC     4616.959496
#
# [736 rows x 7 columns]

# %%
gastoPERC = pd.DataFrame(gastoIES.groupby("Estado")["PERCAPITA"].mean())
gastoPERC = gastoPERC.sort_values(by="PERCAPITA",ascending=True)
gastoPERC["OrdenPERC"]=gastoPERC.reset_index().index+1
gastoPERC=pd.merge(gastoIES,gastoPERC,on="Estado",how="inner").sort_values(by=["OrdenPERC","Anio"],ascending=True)
gastoPERC.rename(columns={"PERCAPITA_x":"PERCAPITA","PERCAPITA_y":"PERCAPITA_mean"},inplace=True)
gastoPERC=gastoPERC.sort_values(by=["Estado","Anio"],ascending=True)
gastoPERC
# Out:
#         Anio sexenio     EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# AGS     1995      S1  Aguascalientes  2.278928  7.917746e+07  10.647619
# AGS     1996      S1  Aguascalientes  1.987116  8.690798e+07  10.914541
# AGS     1997      S1  Aguascalientes  2.143517  9.629624e+07  13.529886
# AGS     1998      S1  Aguascalientes  2.319555  1.003836e+08  13.109835
# AGS     1999      S1  Aguascalientes  2.761372  1.073634e+08  15.017065
# ...      ...     ...             ...       ...           ...        ...
# ZAC     2013      S4       Zacatecas  3.941298  1.694030e+08  21.766645
# ZAC     2014      S4       Zacatecas  3.834181  1.743785e+08  21.374967
# ZAC     2015      S4       Zacatecas  3.856125  1.841990e+08  22.107488
# ZAC     2016      S4       Zacatecas  3.674188  1.918374e+08  21.830197
# ZAC     2017      S4       Zacatecas  3.747525  1.971711e+08  25.655200
#
#           PERCAPITA  PERCAPITA_mean  OrdenPERC
# Estado
# AGS     1959.069682     4000.691352         25
# AGS     1838.158261     4000.691352         25
# AGS     2155.873869     4000.691352         25
# AGS     2388.303511     4000.691352         25
# AGS     2989.039477     4000.691352         25
# ...             ...             ...        ...
# ZAC     4307.035375     2997.863710         12
# ZAC     4276.775771     2997.863710         12
# ZAC     4506.750129     2997.863710         12
# ZAC     4437.413443     2997.863710         12
# ZAC     4616.959496     2997.863710         12
#
# [736 rows x 9 columns]

# %%
gastoPIBmxn = pd.DataFrame(gastoIES.groupby("Estado")["PIBmxn"].mean())
gastoPIBmxn = gastoPIBmxn.sort_values(by="PIBmxn",ascending=True)
gastoPIBmxn["OrdenPIBmxn"]=gastoPIBmxn.reset_index().index+1
gastoPIBmxn["OrdenEndpoint"]=gastoPIBmxn.reset_index().index+1
gastoPIBmxn=pd.merge(gastoIES,gastoPIBmxn,on="Estado",how="inner").sort_values(by=["OrdenPIBmxn","Anio"],ascending=True)
gastoPIBmxn.rename(columns={"PIBmxn_x":"PIBmxn","PIBmxn_y":"PIBmxn_mean"},inplace=True)
gastoPIBmxn=gastoPIBmxn.sort_values(by=["OrdenPIBmxn","Estado","Anio"],ascending=True)
gastoPIBmxn
# Out:
#         Anio sexenio       EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# COL     1995      S1            Colima  3.120261  3.762578e+07  10.549447
# COL     1996      S1            Colima  2.684352  4.093702e+07   9.105518
# COL     1997      S1            Colima  3.053185  4.408892e+07   9.377045
# COL     1998      S1            Colima  3.227215  4.715884e+07  10.881608
# COL     1999      S1            Colima  3.576777  5.171873e+07  13.254989
# ...      ...     ...               ...       ...           ...        ...
# CDMX    2013      S4  Ciudad de México  3.737296  3.083407e+09   8.521787
# CDMX    2014      S4  Ciudad de México  3.022471  3.093859e+09   6.671049
# CDMX    2015      S4  Ciudad de México  3.190114  3.200794e+09   6.742936
# CDMX    2016      S4  Ciudad de México  3.016004  3.341291e+09   5.826136
# CDMX    2017      S4  Ciudad de México  2.908126  3.409016e+09   6.810649
#
#            PERCAPITA   PIBmxn_mean  OrdenPIBmxn  OrdenEndpoint
# Estado
# COL      2269.261021  7.988552e+07            1              1
# COL      2093.342310  7.988552e+07            1              1
# COL      2530.460465  7.988552e+07            1              1
# COL      2825.900874  7.988552e+07            1              1
# COL      3399.547342  7.988552e+07            1              1
# ...              ...           ...          ...            ...
# CDMX    12956.978154  2.611315e+09           32             32
# CDMX    10536.780110  2.611315e+09           32             32
# CDMX    11531.744309  2.611315e+09           32             32
# CDMX    11408.210662  2.611315e+09           32             32
# CDMX    11251.331521  2.611315e+09           32             32
#
# [736 rows x 10 columns]

# %%
gastoPIBmxn["ORPIBmxn"]=gastoPIBmxn.OrdenPIBmxn
gastoPIBmxn
# Out:
#         Anio sexenio       EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# COL     1995      S1            Colima  3.120261  3.762578e+07  10.549447
# COL     1996      S1            Colima  2.684352  4.093702e+07   9.105518
# COL     1997      S1            Colima  3.053185  4.408892e+07   9.377045
# COL     1998      S1            Colima  3.227215  4.715884e+07  10.881608
# COL     1999      S1            Colima  3.576777  5.171873e+07  13.254989
# ...      ...     ...               ...       ...           ...        ...
# CDMX    2013      S4  Ciudad de México  3.737296  3.083407e+09   8.521787
# CDMX    2014      S4  Ciudad de México  3.022471  3.093859e+09   6.671049
# CDMX    2015      S4  Ciudad de México  3.190114  3.200794e+09   6.742936
# CDMX    2016      S4  Ciudad de México  3.016004  3.341291e+09   5.826136
# CDMX    2017      S4  Ciudad de México  2.908126  3.409016e+09   6.810649
#
#            PERCAPITA   PIBmxn_mean  OrdenPIBmxn  OrdenEndpoint  ORPIBmxn
# Estado
# COL      2269.261021  7.988552e+07            1              1         1
# COL      2093.342310  7.988552e+07            1              1         1
# COL      2530.460465  7.988552e+07            1              1         1
# COL      2825.900874  7.988552e+07            1              1         1
# COL      3399.547342  7.988552e+07            1              1         1
# ...              ...           ...          ...            ...       ...
# CDMX    12956.978154  2.611315e+09           32             32        32
# CDMX    10536.780110  2.611315e+09           32             32        32
# CDMX    11531.744309  2.611315e+09           32             32        32
# CDMX    11408.210662  2.611315e+09           32             32        32
# CDMX    11251.331521  2.611315e+09           32             32        32
#
# [736 rows x 11 columns]

# %%
gastoPIBmxn.to_json(r"datos/JSON_PIBmxn.json",orient="table")

# %%
gastoPERC = pd.DataFrame(gastoIES.groupby("Estado")["PERCAPITA"].mean())
gastoPERC = gastoPERC.sort_values(by="PERCAPITA",ascending=True)
gastoPERC["OrdenPERC"]=gastoPERC.reset_index().index+1
gastoPERC["OrdenEndpoint"]=gastoPERC.reset_index().index+1
gastoPERC=pd.merge(gastoIES,gastoPERC,on="Estado",how="inner").sort_values(by=["OrdenPERC","Anio"],ascending=True)
gastoPERC.rename(columns={"PERCAPITA_x":"PERCAPITA","PERCAPITA_y":"PERCAPITA_mean"},inplace=True)
gastoPERC=gastoPERC.sort_values(by=["OrdenPERC","Estado","Anio"],ascending=True)
gastoPERC
# Out:
#         Anio sexenio       EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# CHIS    1995      S1           Chiapas  3.082612  1.282853e+08  12.542548
# CHIS    1996      S1           Chiapas  2.782510  1.327687e+08   8.104573
# CHIS    1997      S1           Chiapas  2.395682  1.432514e+08   6.903133
# CHIS    1998      S1           Chiapas  2.675156  1.452491e+08   8.131984
# CHIS    1999      S1           Chiapas  3.553554  1.497202e+08  10.620692
# ...      ...     ...               ...       ...           ...        ...
# CDMX    2013      S4  Ciudad de México  3.737296  3.083407e+09   8.521787
# CDMX    2014      S4  Ciudad de México  3.022471  3.093859e+09   6.671049
# CDMX    2015      S4  Ciudad de México  3.190114  3.200794e+09   6.742936
# CDMX    2016      S4  Ciudad de México  3.016004  3.341291e+09   5.826136
# CDMX    2017      S4  Ciudad de México  2.908126  3.409016e+09   6.810649
#
#            PERCAPITA  PERCAPITA_mean  OrdenPERC  OrdenEndpoint
# Estado
# CHIS     1059.624317     2355.212141          1              1
# CHIS      967.161306     2355.212141          1              1
# CHIS      878.316264     2355.212141          1              1
# CHIS      972.790184     2355.212141          1              1
# CHIS     1302.927966     2355.212141          1              1
# ...              ...             ...        ...            ...
# CDMX    12956.978154     9498.226880         32             32
# CDMX    10536.780110     9498.226880         32             32
# CDMX    11531.744309     9498.226880         32             32
# CDMX    11408.210662     9498.226880         32             32
# CDMX    11251.331521     9498.226880         32             32
#
# [736 rows x 10 columns]

# %%
gastoPERC["ORPERC"]=gastoPERC.OrdenPERC
gastoPERC
# Out:
#         Anio sexenio       EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# CHIS    1995      S1           Chiapas  3.082612  1.282853e+08  12.542548
# CHIS    1996      S1           Chiapas  2.782510  1.327687e+08   8.104573
# CHIS    1997      S1           Chiapas  2.395682  1.432514e+08   6.903133
# CHIS    1998      S1           Chiapas  2.675156  1.452491e+08   8.131984
# CHIS    1999      S1           Chiapas  3.553554  1.497202e+08  10.620692
# ...      ...     ...               ...       ...           ...        ...
# CDMX    2013      S4  Ciudad de México  3.737296  3.083407e+09   8.521787
# CDMX    2014      S4  Ciudad de México  3.022471  3.093859e+09   6.671049
# CDMX    2015      S4  Ciudad de México  3.190114  3.200794e+09   6.742936
# CDMX    2016      S4  Ciudad de México  3.016004  3.341291e+09   5.826136
# CDMX    2017      S4  Ciudad de México  2.908126  3.409016e+09   6.810649
#
#            PERCAPITA  PERCAPITA_mean  OrdenPERC  OrdenEndpoint  ORPERC
# Estado
# CHIS     1059.624317     2355.212141          1              1       1
# CHIS      967.161306     2355.212141          1              1       1
# CHIS      878.316264     2355.212141          1              1       1
# CHIS      972.790184     2355.212141          1              1       1
# CHIS     1302.927966     2355.212141          1              1       1
# ...              ...             ...        ...            ...     ...
# CDMX    12956.978154     9498.226880         32             32      32
# CDMX    10536.780110     9498.226880         32             32      32
# CDMX    11531.744309     9498.226880         32             32      32
# CDMX    11408.210662     9498.226880         32             32      32
# CDMX    11251.331521     9498.226880         32             32      32
#
# [736 rows x 11 columns]

# %%
gastoPERC.to_json(r"datos/JSON_PERC.json",orient="table")

# %%
gastoPIB = pd.DataFrame(gastoIES.groupby("Estado")["PIB"].mean())
gastoPIB = gastoPIB.sort_values(by="PIB",ascending=True)
gastoPIB["OrdenPIB"]=gastoPIB.reset_index().index+1
gastoPIB["OrdenEndpoint"]=gastoPIB.reset_index().index+1
gastoPIB=pd.merge(gastoIES,gastoPIB,on="Estado",how="inner").sort_values(by=["OrdenPIB","Anio"],ascending=True)
gastoPIB.rename(columns={"PIB_x":"PIB","PIB_y":"PIB_mean"},inplace=True)
gastoPIB
# Out:
#         Anio sexenio EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# CAMP    1995      S1    Campeche  1.537610  9.870427e+07   6.582009
# CAMP    1996      S1    Campeche  1.409711  9.974501e+07   4.817801
# CAMP    1997      S1    Campeche  1.591786  1.025906e+08   5.386548
# CAMP    1998      S1    Campeche  1.955212  9.328499e+07   4.810215
# CAMP    1999      S1    Campeche  2.076391  1.061146e+08   7.514958
# ...      ...     ...         ...       ...           ...        ...
# NAY     2013      S4     Nayarit  4.652251  1.195352e+08  21.766850
# NAY     2014      S4     Nayarit  4.195087  1.245053e+08  18.986366
# NAY     2015      S4     Nayarit  4.287882  1.340607e+08  19.823885
# NAY     2016      S4     Nayarit  3.981486  1.427993e+08  20.340046
# NAY     2017      S4     Nayarit  4.073215  1.505059e+08  23.593870
#
#           PERCAPITA  PIB_mean  OrdenPIB  OrdenEndpoint
# Estado
# CAMP    2409.419805  1.125302         1              1
# CAMP    2180.641158  1.125302         1              1
# CAMP    2476.466433  1.125302         1              1
# CAMP    2707.429223  1.125302         1              1
# CAMP    3205.240990  1.125302         1              1
# ...             ...       ...       ...            ...
# NAY     4719.165012  4.234037        32             32
# NAY     4348.233386  4.234037        32             32
# NAY     4697.155252  4.234037        32             32
# NAY     4562.289993  4.234037        32             32
# NAY     4832.969703  4.234037        32             32
#
# [736 rows x 10 columns]

# %%
gastoPIB.to_json(r"datos/JSON_PIB.json",orient="table")

# %%
gastoGPT = pd.DataFrame(gastoIES.groupby("Estado")["GPT"].mean())
gastoGPT = gastoGPT.sort_values(by="GPT",ascending=True)
gastoGPT["OrdenGPT"]=gastoGPT.reset_index().index+1
gastoGPT["OrdenEndpoint"]=gastoGPT.reset_index().index+1
gastoGPT=pd.merge(gastoIES,gastoGPT,on="Estado",how="inner").sort_values(by=["OrdenGPT","Anio"],ascending=True)
gastoGPT.rename(columns={"GPT_x":"GPT","GPT_y":"GPT_mean"},inplace=True)
gastoGPT
# Out:
#         Anio sexenio EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# CAMP    1995      S1    Campeche  1.537610  9.870427e+07   6.582009
# CAMP    1996      S1    Campeche  1.409711  9.974501e+07   4.817801
# CAMP    1997      S1    Campeche  1.591786  1.025906e+08   5.386548
# CAMP    1998      S1    Campeche  1.955212  9.328499e+07   4.810215
# CAMP    1999      S1    Campeche  2.076391  1.061146e+08   7.514958
# ...      ...     ...         ...       ...           ...        ...
# JAL     2013      S4     Jalisco  2.774804  1.174940e+09  30.261226
# JAL     2014      S4     Jalisco  2.786809  1.226708e+09  29.407469
# JAL     2015      S4     Jalisco  2.673096  1.313154e+09  27.847115
# JAL     2016      S4     Jalisco  2.459699  1.415365e+09  26.469881
# JAL     2017      S4     Jalisco  2.495307  1.466416e+09  27.611914
#
#           PERCAPITA   GPT_mean  OrdenGPT  OrdenEndpoint
# Estado
# CAMP    2409.419805   5.664379         1              1
# CAMP    2180.641158   5.664379         1              1
# CAMP    2476.466433   5.664379         1              1
# CAMP    2707.429223   5.664379         1              1
# CAMP    3205.240990   5.664379         1              1
# ...             ...        ...       ...            ...
# JAL     4210.927569  29.776192        32             32
# JAL     4361.567434  29.776192        32             32
# JAL     4425.757595  29.776192        32             32
# JAL     4339.681327  29.776192        32             32
# JAL     4511.382516  29.776192        32             32
#
# [736 rows x 10 columns]

# %%
gastoGPT.to_json(r"datos/JSON_GPT.json",orient="table")

# %%
gastoALF = pd.DataFrame(gastoIES.groupby("Estado")["GPT"].mean())
gastoALF = gastoALF.sort_values(by="Estado",ascending=True)
gastoALF["Orden"]=gastoALF.reset_index().index+1
gastoALF=pd.merge(gastoIES,gastoALF,on="Estado",how="inner").sort_values(by=["Estado","Anio"],ascending=True)
gastoALF.rename(columns={"GPT_x":"GPT","GPT_y":"GPT_mean"},inplace=True)
gastoALF
# Out:
#         Anio sexenio     EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# AGS     1995      S1  Aguascalientes  2.278928  7.917746e+07  10.647619
# AGS     1996      S1  Aguascalientes  1.987116  8.690798e+07  10.914541
# AGS     1997      S1  Aguascalientes  2.143517  9.629624e+07  13.529886
# AGS     1998      S1  Aguascalientes  2.319555  1.003836e+08  13.109835
# AGS     1999      S1  Aguascalientes  2.761372  1.073634e+08  15.017065
# ...      ...     ...             ...       ...           ...        ...
# ZAC     2013      S4       Zacatecas  3.941298  1.694030e+08  21.766645
# ZAC     2014      S4       Zacatecas  3.834181  1.743785e+08  21.374967
# ZAC     2015      S4       Zacatecas  3.856125  1.841990e+08  22.107488
# ZAC     2016      S4       Zacatecas  3.674188  1.918374e+08  21.830197
# ZAC     2017      S4       Zacatecas  3.747525  1.971711e+08  25.655200
#
#           PERCAPITA   GPT_mean  Orden
# Estado
# AGS     1959.069682  20.082444      1
# AGS     1838.158261  20.082444      1
# AGS     2155.873869  20.082444      1
# AGS     2388.303511  20.082444      1
# AGS     2989.039477  20.082444      1
# ...             ...        ...    ...
# ZAC     4307.035375  18.515251     32
# ZAC     4276.775771  18.515251     32
# ZAC     4506.750129  18.515251     32
# ZAC     4437.413443  18.515251     32
# ZAC     4616.959496  18.515251     32
#
# [736 rows x 9 columns]

# %%
gastoALF.to_json(r"datos/JSON_ALF.json",orient="table")

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoPERC.to_excel(writer, sheet_name="PERC")
  gastoPIB.to_excel(writer, sheet_name="PIB")
  gastoGPT.to_excel(writer, sheet_name="GPT")
  gastoALF.to_excel(writer, sheet_name="ALF")

# %%
gastoIES
# Out:
#         Anio sexenio          EstadoPrint       PIB        PIBmxn        GPT  \
# Estado
# AGS     1995      S1       Aguascalientes  2.278928  7.917746e+07  10.647619
# BC      1995      S1      Baja California  2.163063  2.294365e+08  22.601979
# BCS     1995      S1  Baja California Sur  3.742114  3.864674e+07  21.956918
# CAMP    1995      S1             Campeche  1.537610  9.870427e+07   6.582009
# COAH    1995      S1             Coahuila  2.400249  2.400484e+08  17.083340
# ...      ...     ...                  ...       ...           ...        ...
# TAMPS   2017      S4           Tamaulipas  3.181874  6.078901e+08  18.173028
# TLAX    2017      S4             Tlaxcala  4.977256  1.154003e+08  28.274960
# VER     2017      S4             Veracruz  3.916907  9.402165e+08  17.513495
# YUC     2017      S4              Yucatán  4.249854  3.004113e+08  22.314929
# ZAC     2017      S4            Zacatecas  3.747525  1.971711e+08  25.655200
#
#           PERCAPITA
# Estado
# AGS     1959.069682
# BC      2317.759096
# BCS     3609.493866
# CAMP    2409.419805
# COAH    2621.670253
# ...             ...
# TAMPS   5339.333865
# TLAX    4374.314206
# VER     4510.971605
# YUC     5875.742148
# ZAC     4616.959496
#
# [736 rows x 7 columns]

# %%
presis = [
    "Ernesto Zedillo Ponce de León", 
    "Vicente Fox Quesada", 
    "Felipe Calderón Hinojosa",
    "Enrique Peña Nieto"]

presidenteCol = pd.cut(gastoIES.Anio, bins=sexenios, precision=0, right=False, labels=presis)
gastoIES.insert(1, "presidente", presidenteCol)
gastoIES.head()
# Out:
#         Anio                     presidente sexenio          EstadoPrint  \
# Estado
# AGS     1995  Ernesto Zedillo Ponce de León      S1       Aguascalientes
# BC      1995  Ernesto Zedillo Ponce de León      S1      Baja California
# BCS     1995  Ernesto Zedillo Ponce de León      S1  Baja California Sur
# CAMP    1995  Ernesto Zedillo Ponce de León      S1             Campeche
# COAH    1995  Ernesto Zedillo Ponce de León      S1             Coahuila
#
#              PIB        PIBmxn        GPT    PERCAPITA
# Estado
# AGS     2.278928  7.917746e+07  10.647619  1959.069682
# BC      2.163063  2.294365e+08  22.601979  2317.759096
# BCS     3.742114  3.864674e+07  21.956918  3609.493866
# CAMP    1.537610  9.870427e+07   6.582009  2409.419805
# COAH    2.400249  2.400484e+08  17.083340  2621.670253

# %%
gastoIES.sexenio.unique()
# Out:
# ['S1', 'S2', 'S3', 'S4']
# Categories (4, object): ['S1' < 'S2' < 'S3' < 'S4']

# %%
gastoIES=gastoIES.groupby(["Estado", "sexenio"]).mean()

# %%
meanPERC = pd.DataFrame(gastoIES.groupby("Estado")["PERCAPITA"].mean())
meanPERC = meanPERC.sort_values(by="PERCAPITA",ascending=True)
meanPERC["Orden"]=meanPERC.reset_index().index+1
meanPERC=pd.merge(meanPERC,gastoIES,on="Estado",how="inner").sort_values(by=["Orden","Anio"],ascending=True)
meanPERC.rename(columns={"PERCAPITA_x":"PERCAPITA","PERCAPITA_y":"PERCAPITA_mean"},inplace=True)
meanPERC
# Out:
#           PERCAPITA  Orden    Anio       PIB        PIBmxn        GPT  \
# Estado
# CHIS    2401.625922      1  1997.5  3.031357  1.436119e+08   9.543822
# CHIS    2401.625922      1  2003.5  3.744797  2.363310e+08  15.070000
# CHIS    2401.625922      1  2009.5  4.825630  3.110425e+08  17.701667
# CHIS    2401.625922      1  2015.0  5.478919  3.325513e+08  18.481366
# MICH    2446.389827      2  1997.5  2.374804  1.983033e+08  14.648660
# ...             ...    ...     ...       ...           ...        ...
# BCS     5607.353616     31  2015.0  3.285400  1.538414e+08  17.387763
# CDMX    9583.176133     32  1997.5  2.882883  1.910708e+09  13.131239
# CDMX    9583.176133     32  2003.5  3.177194  2.502050e+09  10.718333
# CDMX    9583.176133     32  2009.5  3.584998  2.909223e+09   9.536667
# CDMX    9583.176133     32  2015.0  3.174802  3.225673e+09   6.914511
#
#         PERCAPITA_mean
# Estado
# CHIS       1103.833708
# CHIS       1947.593523
# CHIS       3085.933565
# CHIS       3469.142892
# MICH       1142.041314
# ...                ...
# BCS        6532.998440
# CDMX       6268.273877
# CDMX       8855.970946
# CDMX      11671.450757
# CDMX      11537.008951
#
# [128 rows x 7 columns]

# %%
meanPERC.to_json(r"datos/JSON_meanPERC.json",orient="table")

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoIES.to_excel(writer, sheet_name="IES")
  gastoPERC.to_excel(writer, sheet_name="PERC")
  gastoPIB.to_excel(writer, sheet_name="PIB")
  gastoGPT.to_excel(writer, sheet_name="GPT")
  gastoALF.to_excel(writer, sheet_name="ALF")
  meanPERC.to_excel(writer, sheet_name="meanPERC")

# %%
meanPIBmxn = pd.DataFrame(gastoIES.groupby("Estado")["PIBmxn"].mean())
meanPIBmxn = meanPIBmxn.sort_values(by="PIBmxn",ascending=True)
meanPIBmxn["Orden"]=meanPIBmxn.reset_index().index+1
meanPIBmxn=pd.merge(meanPIBmxn,gastoIES,on="Estado",how="inner").sort_values(by=["Orden","Anio"],ascending=True)
meanPIBmxn.rename(columns={"PIBmxn_x":"PIBmxn","PIBmxn_y":"PIBmxn_mean"},inplace=True)
meanPIBmxn
# Out:
#               PIBmxn  Orden    Anio       PIB   PIBmxn_mean        GPT  \
# Estado
# COL     8.130528e+07      1  1997.5  3.222271  4.600452e+07  10.633101
# COL     8.130528e+07      1  2003.5  3.706174  7.021870e+07  13.263333
# COL     8.130528e+07      1  2009.5  3.663271  9.503823e+07  11.938333
# COL     8.130528e+07      1  2015.0  3.624347  1.139597e+08  11.692702
# TLAX    8.232919e+07      2  1997.5  3.002392  4.443095e+07  15.775308
# ...              ...    ...     ...       ...           ...        ...
# EDOMEX  1.279859e+09     31  2015.0  4.210475  1.699874e+09  30.597387
# CDMX    2.636914e+09     32  1997.5  2.882883  1.910708e+09  13.131239
# CDMX    2.636914e+09     32  2003.5  3.177194  2.502050e+09  10.718333
# CDMX    2.636914e+09     32  2009.5  3.584998  2.909223e+09   9.536667
# CDMX    2.636914e+09     32  2015.0  3.174802  3.225673e+09   6.914511
#
#            PERCAPITA
# Estado
# COL      2792.484812
# COL      4476.852641
# COL      5337.516569
# COL      5697.959398
# TLAX     1391.276494
# ...              ...
# EDOMEX   4237.014192
# CDMX     6268.273877
# CDMX     8855.970946
# CDMX    11671.450757
# CDMX    11537.008951
#
# [128 rows x 7 columns]

# %%
meanPIBmxn.to_json(r"datos/JSON_meanPIBmxn.json",orient="table")

# %%
meanPIB = pd.DataFrame(gastoIES.groupby("Estado")["PIB"].mean())
meanPIB = meanPIB.sort_values(by="PIB",ascending=True)
meanPIB["Orden"]=meanPIB.reset_index().index+1
meanPIB=pd.merge(meanPIB,gastoIES,on="Estado",how="inner").sort_values(by=["Orden","Anio"],ascending=True)
meanPIB.rename(columns={"PIB_x":"PIB","PIB_y":"PIB_mean"},inplace=True)
meanPIB
# Out:
#              PIB  Orden    Anio  PIB_mean        PIBmxn        GPT  \
# Estado
# CAMP    1.120061      1  1997.5  1.768191  1.032599e+08   6.018588
# CAMP    1.120061      1  2003.5  1.106372  5.618543e+08   7.696667
# CAMP    1.120061      1  2009.5  0.606164  9.070858e+08   5.236667
# CAMP    1.120061      1  2015.0  0.999517  6.012698e+08   3.313836
# NL      1.779428      2  1997.5  1.929468  5.783445e+08  24.470076
# ...          ...    ...     ...       ...           ...        ...
# OAX     4.260568     31  2015.0  5.259814  2.978698e+08  18.792112
# CHIS    4.270176     32  1997.5  3.031357  1.436119e+08   9.543822
# CHIS    4.270176     32  2003.5  3.744797  2.363310e+08  15.070000
# CHIS    4.270176     32  2009.5  4.825630  3.110425e+08  17.701667
# CHIS    4.270176     32  2015.0  5.478919  3.325513e+08  18.481366
#
#           PERCAPITA
# Estado
# CAMP    2740.754515
# CAMP    4751.925666
# CAMP    6528.398108
# CAMP    6154.105895
# NL      2940.910871
# ...             ...
# OAX     3906.549440
# CHIS    1103.833708
# CHIS    1947.593523
# CHIS    3085.933565
# CHIS    3469.142892
#
# [128 rows x 7 columns]

# %%
meanPIB.to_json(r"datos/JSON_meanPIB.json",orient="table")

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoPERC.to_excel(writer, sheet_name="PERC")
  gastoPIB.to_excel(writer, sheet_name="PIB")
  gastoGPT.to_excel(writer, sheet_name="GPT")
  gastoALF.to_excel(writer, sheet_name="ALF")
  meanPERC.to_excel(writer, sheet_name="meanPERC")
  meanPIB.to_excel(writer, sheet_name="meanPIB")

# %%
meanGPT = pd.DataFrame(gastoIES.groupby("Estado")["GPT"].mean())
meanGPT = meanGPT.sort_values(by="GPT",ascending=True)
meanGPT["Orden"]=meanGPT.reset_index().index+1
meanGPT=pd.merge(meanGPT,gastoIES,on="Estado",how="inner").sort_values(by=["Orden","Anio"],ascending=True)
meanGPT.rename(columns={"GPT_x":"GPT","GPT_y":"GPT_mean"},inplace=True)
meanGPT
# Out:
#               GPT  Orden    Anio       PIB        PIBmxn   GPT_mean  \
# Estado
# CAMP     5.566440      1  1997.5  1.768191  1.032599e+08   6.018588
# CAMP     5.566440      1  2003.5  1.106372  5.618543e+08   7.696667
# CAMP     5.566440      1  2009.5  0.606164  9.070858e+08   5.236667
# CAMP     5.566440      1  2015.0  0.999517  6.012698e+08   3.313836
# CDMX    10.075187      2  1997.5  2.882883  1.910708e+09  13.131239
# ...           ...    ...     ...       ...           ...        ...
# EDOMEX  28.010935     31  2015.0  4.210475  1.699874e+09  30.597387
# JAL     29.715497     32  1997.5  2.370671  5.447565e+08  26.462468
# JAL     29.715497     32  2003.5  2.631433  8.516092e+08  34.150000
# JAL     29.715497     32  2009.5  2.769192  1.069852e+09  29.930000
# JAL     29.715497     32  2015.0  2.637943  1.319316e+09  28.319521
#
#           PERCAPITA
# Estado
# CAMP    2740.754515
# CAMP    4751.925666
# CAMP    6528.398108
# CAMP    6154.105895
# CDMX    6268.273877
# ...             ...
# EDOMEX  4237.014192
# JAL     2039.601365
# JAL     3261.681925
# JAL     4010.517066
# JAL     4369.863288
#
# [128 rows x 7 columns]

# %%
meanGPT.to_json(r"datos/JSON_meanGPT.json",orient="table")

# %%
with pd.ExcelWriter("GASTO_CSV.xlsx") as writer:
  gastoPERC.to_excel(writer, sheet_name="PERC")
  gastoPIB.to_excel(writer, sheet_name="PIB")
  gastoGPT.to_excel(writer, sheet_name="GPT")
  gastoALF.to_excel(writer, sheet_name="ALF")
  meanPERC.to_excel(writer, sheet_name="meanPERC")
  meanPIB.to_excel(writer, sheet_name="meanPIB")
  meanGPT.to_excel(writer, sheet_name="meanGPT")
