# %%
import xlrd
# comentarios
#path: direccion de archivo

import os
import pandas as pd
import numpy as np
import array as arr
import altair as alt

pd.set_option("display.max_columns",None)

# %%
SexeniosPIB = pd.read_csv("SexeniosPIB.csv")

# %%
SexeniosPIB
# Out:
#    ENTIDAD               NOMBRE     S1     S2     S3     S4   S1vsS2   S2vsS3  \
# 0      AGS       Aguascalientes  2.32%  2.79%  3.11%  2.93%   20.02%   11.40%
# 1       BC      Baja California  1.99%  1.99%  2.69%  2.87%    0.40%   34.82%
# 2      BCS  Baja California Sur  3.72%  3.44%  3.18%  3.29%   -7.51%   -7.39%
# 3     CAMP             Campeche  1.77%  1.11%  0.61%  1.00%  -37.43%  -45.21%
# 4     CDMX     Ciudad de México  2.88%  3.18%  3.58%  3.17%   10.21%   12.84%
# 5     CHIH            Chihuahua  1.89%  2.50%  3.15%  2.89%   32.14%   25.90%
# 6     CHIS              Chiapas  3.03%  3.74%  4.83%  5.48%   23.54%   28.86%
# 7     COAH             Coahuila  2.30%  2.34%  2.10%  2.15%    1.80%  -10.32%
# 8      COL               Colima  3.22%  3.71%  3.66%  3.62%   15.02%   -1.16%
# 9      DGO              Durango  2.93%  3.67%  3.75%  3.65%   25.44%    2.19%
# 10     GRO             Guerrero  2.80%  3.71%  4.80%  5.29%   32.61%   29.32%
# 11     GTO           Guanajuato  2.14%  2.64%  3.21%  2.94%   23.05%   21.81%
# 12     HGO              Hidalgo  2.78%  3.52%  3.71%  3.75%   26.43%    5.51%
# 13     JAL              Jalisco  2.37%  2.63%  2.77%  2.64%   11.00%    5.24%
# 14     MEX     Estado de México  1.67%  2.46%  3.54%  4.21%   47.52%   43.74%
# 15    MICH            Michoacan  2.37%  2.96%  3.43%  3.62%   24.67%   15.97%
# 16     MOR              Morelos  2.40%  2.88%  3.60%  3.85%   19.68%   25.02%
# 17     NAY              Nayarit  4.25%  4.17%  4.27%  4.24%   -1.80%    2.40%
# 18      NL           Nuevo León  1.93%  1.79%  1.68%  1.72%   -7.27%   -6.21%
# 19     OAX               Oaxaca  3.00%  3.91%  4.87%  5.26%   30.63%   24.50%
# 20     PUE               Puebla  2.04%  2.69%  3.17%  3.45%   31.82%   18.03%
# 21     QRO            Queretaro  1.69%  1.92%  1.91%  1.86%   13.70%   -0.97%
# 22    QROO         Quintana Roo  1.79%  2.01%  2.41%  2.46%   12.36%   20.10%
# 23     SIN              Sinaloa  3.22%  3.39%  3.29%  3.24%    5.11%   -2.90%
# 24     SLP      San Luis Potosí  2.37%  2.82%  2.87%  2.78%   19.02%    1.78%
# 25     SON               Sonora  2.49%  2.63%  2.43%  3.02%    5.72%   -7.52%
# 26     TAB              Tabasco  3.48%  3.86%  2.13%  2.42%   11.10%  -44.97%
# 27   TAMPS           Tamaulipas  2.49%  2.60%  2.77%  3.27%    4.46%    6.25%
# 28    TLAX             Tlaxcala  3.00%  3.73%  4.57%  5.00%   24.18%   22.63%
# 29     VER             Veracruz  3.10%  3.55%  3.56%  3.69%   14.30%    0.42%
# 30     YUC              Yucatan  3.69%  3.91%  4.18%  4.59%    5.79%    7.08%
# 31     ZAC            Zacatecas  2.97%  3.82%  3.53%  3.81%   28.62%   -7.53%
#
#      S3vsS4
# 0    -5.82%
# 1     6.73%
# 2     3.18%
# 3    64.89%
# 4   -11.44%
# 5    -8.24%
# 6    13.54%
# 7     2.56%
# 8    -1.06%
# 9    -2.73%
# 10   10.14%
# 11   -8.43%
# 12    0.99%
# 13   -4.74%
# 14   19.05%
# 15    5.32%
# 16    7.12%
# 17   -0.85%
# 18    2.55%
# 19    7.94%
# 20    8.90%
# 21   -2.16%
# 22    2.00%
# 23   -1.50%
# 24   -2.98%
# 25   24.00%
# 26   13.89%
# 27   18.25%
# 28    9.35%
# 29    3.50%
# 30    9.63%
# 31    7.87%

# %%
SexeniosPIB.to_json(r"datos/JSON_SexeniosPIB.json",orient="table")

# %%
import json

# Load the JSON data
with open("datos/JSON_SexeniosPIB.json") as f:
    data = json.load(f)

# Extract the column names
fields = data['schema']['fields']
column_names = [field['name'] for field in fields]

# Print the column names
print(column_names)
# Out:
# ['index', 'ENTIDAD', 'NOMBRE', 'S1', 'S2', 'S3', 'S4', 'S1vsS2', 'S2vsS3', 'S3vsS4']
